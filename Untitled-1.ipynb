# %%
import streamlit as st
import pickle
import pandas as pd
model=pickle.load(open("cox_model.pkl","rb"))
df=pd.read_excel("D:\Projects\医院\曹钰硕\\2026_01_23_文章修改\训练集分组.xlsx")
df["治疗方式1"]=1
df["治疗方式2"]=1
model.predict_median(df.iloc[0:2,:])
# Out:
# 0    224.0
# 1    180.0
# Name: 0.5, dtype: float64

# %%
import seaborn as sns
import numpy as np
sns.heatmap(pd.DataFrame(np.ones(100)))
# Out:
# <Axes: >

# %%
import pickle
import numpy as np
class CoxModelPredict():
    def __init__(self,cox_model_path,shap_model_path):
        self.feature_col_list=["治疗方式2","治疗方式3","cN分期","腹水分级","腹膜转移评分二分","肝脏转移"]
        self.load_model(cox_model_path,shap_model_path)
    
    def load_model(self,cox_model_path,shap_model_path):
        self.model=pickle.load(open(cox_model_path,"rb"))
        self.shap_explainer=pickle.load(open(shap_model_path,"rb"))

    def predict_one_case(self,threshold=0.74,case_feature_dic=None,time_point_list=[]):
        xdata=np.array([[case_feature_dic[x] for x in self.feature_col_list]])
        risk=self.model.predict_partial_hazard(xdata).iloc[0]
        group="高危组"
        rel={"risk":risk,"group":group}
        for time_point in time_point_list:
            survival_prob=self.model.predict_survival_function(xdata,times=time_point).iloc[0,0]
            rel[time_point]=survival_prob
        return rel

    def shap_one_case(self,case_feature_dic):
        
        pass
        
    def predict_group(self,):
        pass
    def shape_group(self):
        pass
    def plot_group_at_timepoint(self):
        pass
        
cox_model_path="cox_model.pkl"
shap_model_path="shap_model.pkl"
c=CoxModelPredict(cox_model_path,shap_model_path)
c.predict_one_case(case_feature_dic={"治疗方式2":1,"治疗方式3":1,"cN分期":1,"腹水分级":1,"腹膜转移评分二分":1,"肝脏转移":1},time_point_list=[10,20,40])
# Out:
# 28.82406949094109
# {'risk': np.float64(28.82406949094109),
#  'group': '高危组',
#  10: np.float64(0.8528347598768045),
#  20: np.float64(0.8528347598768045),
#  40: np.float64(0.750367943975476)}

# %%
model=pickle.load(open("shap_model.pkl","rb"))
model(np.array([[2,3,4,4,5]]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 2
#       1 model=pickle.load(open("shap_model.pkl","rb"))
# ----> 2 model(np.array([[2,3,4,4,5]]))
#
# File d:\biancheng\Anaconda3\envs\streamlit\lib\site-packages\shap\explainers\_exact.py:84, in ExactExplainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, interactions, silent, *args)
#      81 """Explains the output of model(*args), where args represents one or more parallel iterators."""
#      82 # we entirely rely on the general call implementation, we override just to remove **kwargs
#      83 # from the function signature
# ---> 84 return super().__call__(
#      85     *args,
#      86     max_evals=max_evals,
#      87     main_effects=main_effects,
#      88     error_bounds=error_bounds,
#      89     batch_size=batch_size,
#      90     interactions=interactions,
#      91     silent=silent,
#      92 )
#
# File d:\biancheng\Anaconda3\envs\streamlit\lib\site-packages\shap\explainers\_explainer.py:366, in Explainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     364     feature_names = [[] for _ in range(len(args))]
#     365 for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__ + " explainer", silent):
# --> 366     row_result = self.explain_row(
#     367         *row_args,
#     368         max_evals=max_evals,
#     369         main_effects=main_effects,
#     370         error_bounds=error_bounds,
#     371         batch_size=batch_size,
#     372         outputs=outputs,
#     373         silent=silent,
#     374         **kwargs,
#     375     )
#     376     values.append(row_result.get("values", None))
#     377     output_indices.append(row_result.get("output_indices", None))
#
# File d:\biancheng\Anaconda3\envs\streamlit\lib\site-packages\shap\explainers\_exact.py:130, in ExactExplainer.explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, interactions, silent, *row_args)
#     127         extended_delta_indexes[i] = inds[delta_indexes[i]]
#     129 # run the model
# --> 130 outputs = fm(extended_delta_indexes, zero_index=0, batch_size=batch_size)
#     132 # Shapley values
#     133 # Care: Need to distinguish between `True` and `1`
#     134 if interactions is False or (interactions == 1 and interactions is not True):
#     135     # loop over all the outputs to update the rows
#
# File d:\biancheng\Anaconda3\envs\streamlit\lib\site-packages\shap\utils\_masked_model.py:57, in MaskedModel.__call__(self, masks, zero_index, batch_size)
#      55 if len(masks.shape) == 1:
#      56     if getattr(self.masker, "supports_delta_masking", False):
# ---> 57         return self._delta_masking_call(masks, zero_index=zero_index, batch_size=batch_size)
#      59     # we need to convert from delta masking to a full masking call because we were given a delta masking
#      60     # input but the masker does not support delta masking
#      61     else:
#      62         full_masks = np.zeros((int(np.sum(masks >= 0)), self._masker_cols), dtype=bool)
#
# File d:\biancheng\Anaconda3\envs\streamlit\lib\site-packages\shap\utils\_masked_model.py:209, in MaskedModel._delta_masking_call(self, masks, zero_index, batch_size)
#     206     batch_positions[i + 1] = batch_positions[i] + num_varying_rows[i]
#     208 # joined_masked_inputs = self._stack_inputs(all_masked_inputs)
# --> 209 outputs = self.model(*subset_masked_inputs)
#     210 _assert_output_input_match(subset_masked_inputs, outputs)
#     212 if self.linearize_link and self.link != links.identity and self._linearizing_weights is None:
#
# File d:\biancheng\Anaconda3\envs\streamlit\lib\site-packages\shap\models\_model.py:23, in Model.__call__(self, *args)
#      22 def __call__(self, *args):
# ---> 23     out = self.inner_model(*args)
#      24     is_tensor = safe_isinstance(out, "torch.Tensor")
#      25     out = out.cpu().detach().numpy() if is_tensor else np.array(out)
#
# File d:\biancheng\Anaconda3\envs\streamlit\lib\site-packages\lifelines\fitters\coxph_fitter.py:2251, in SemiParametricPHFitter.predict_partial_hazard(self, X)
#    2233 def predict_partial_hazard(self, X: Union[ndarray, DataFrame]) -> pd.Series:
#    2234     r"""
#    2235     Returns the partial hazard for the individuals, partial since the
#    2236     baseline hazard is not included. Equal to :math:`\exp{(x - mean(x_{train}))'\beta}`
#    (...)
#    2249     same as the training dataset.
#    2250     """
# -> 2251     return exp(self.predict_log_partial_hazard(X))
#
# File d:\biancheng\Anaconda3\envs\streamlit\lib\site-packages\lifelines\fitters\coxph_fitter.py:2287, in SemiParametricPHFitter.predict_log_partial_hazard(self, X)
#    2283 index = utils._get_index(X)
#    2285 if isinstance(X, pd.DataFrame):
# -> 2287     X = self.regressors.transform_df(X)["beta_"]
#    2288     X = X.values
#    2290 X = X.astype(float)
#
# File d:\biancheng\Anaconda3\envs\streamlit\lib\site-packages\lifelines\utils\__init__.py:1914, in CovariateParameterMappings.transform_df(self, df)
#    1912     if self.force_intercept:
#    1913         df = self.add_intercept_col(df)
# -> 1914     X = df[transform]
#    1915 else:
#    1916     raise ValueError("Unexpected transform.")
#
# File d:\biancheng\Anaconda3\envs\streamlit\lib\site-packages\pandas\core\frame.py:4119, in DataFrame.__getitem__(self, key)
#    4117     if is_iterator(key):
#    4118         key = list(key)
# -> 4119     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4121 # take() does not accept boolean indexers
#    4122 if getattr(indexer, "dtype", None) == bool:
#
# File d:\biancheng\Anaconda3\envs\streamlit\lib\site-packages\pandas\core\indexes\base.py:6212, in Index._get_indexer_strict(self, key, axis_name)
#    6209 else:
#    6210     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6212 self._raise_if_missing(keyarr, indexer, axis_name)
#    6214 keyarr = self.take(indexer)
#    6215 if isinstance(key, Index):
#    6216     # GH 42790 - Preserve name from an Index
#
# File d:\biancheng\Anaconda3\envs\streamlit\lib\site-packages\pandas\core\indexes\base.py:6264, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6261     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6263 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6264 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['治疗方式1', '治疗方式2'] not in index"

# %%
model.predict_survival_function(np.array([[2,3,4,4,5,5]]),times=10)
# Out:
#         0
# 10.0  0.0

# %%
from lifelines import CoxPHFitter
